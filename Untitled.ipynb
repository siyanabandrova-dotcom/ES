# %%
import pandas as pd

# %% [markdown]
# ## Eval Results

# %%
eval_results = pd.read_csv("top_runs_per_metric.csv")
eval_results = eval_results[eval_results.step != 0]
eval_results
# Out:
#                               metric  step  \
# 1   eval/olympiad_bench_mean_fitness    10
# 2   eval/olympiad_bench_mean_fitness    20
# 4          eval/minerva_mean_fitness    10
# 5          eval/minerva_mean_fitness    20
# 7             eval/math_mean_fitness    10
# 8             eval/math_mean_fitness    20
# 10           eval/gsm8k_mean_fitness    10
# 11           eval/gsm8k_mean_fitness    20
# 13           eval/asdiv_mean_fitness    10
# 14           eval/asdiv_mean_fitness    20
# 16             eval/amc_mean_fitness    10
# 17             eval/amc_mean_fitness    20
# 19          eval/aime24_mean_fitness    10
# 20          eval/aime24_mean_fitness    20
#
#                                             rank1_run  rank1_value  \
# 1   hyperparam-sweep-4B-math2_deepscaler40k-Qwen3-...     0.445312
# 2   hyperparam-sweep-4B-math2_deepscaler40k-Qwen3-...     0.296875
# 4   hyperparam-sweep-4B-math2_deepscaler40k-Qwen3-...     0.414062
# ...

# %%
rank1_run_top_runs = eval_results["rank1_run"].value_counts()
rank1_run_top_runs
# Out:
# rank1_run
# hyperparam-sweep-4B-math2_deepscaler40k-Qwen3-4B-P16384-B16-S1-std-scale_lr-l4096-n4-lr0.0002-sigma0.001-r1-alpha1-seed0-gpus64--1771791074     6
# hyperparam-sweep-4B-math2_deepscaler40k-Qwen3-4B-P16384-B16-S1-std-scale_lr-l4096-n4-lr1.6e-05-sigma0.001-r1-alpha1-seed0-gpus64--1771791224    6
# hyperparam-sweep-4B-math2_deepscaler40k-Qwen3-4B-P16384-B16-S1-std-scale_lr-l4096-n4-lr4e-05-sigma0.0002-r1-alpha1-seed0-gpus64--1771791333     1
# hyperparam-sweep-4B-math2_deepscaler40k-Qwen3-4B-P16384-B16-S1-std-scale_lr-l4096-n4-lr4e-05-sigma0.001-r1-alpha1-seed0-gpus64--1771791140      1
# Name: count, dtype: int64

# %%
rank2_run_top_runs = eval_results["rank2_run"].value_counts()
rank2_run_top_runs
# Out:
# rank2_run
# hyperparam-sweep-4B-math2_deepscaler40k-Qwen3-4B-P16384-B16-S1-std-scale_lr-l4096-n4-lr4e-05-sigma0.0002-r1-alpha1-seed0-gpus64--1771791333     6
# hyperparam-sweep-4B-math2_deepscaler40k-Qwen3-4B-P512-B16-S1-std-scale_lr-l4096-n4-lr0.0002-sigma0.001-r1-alpha1-seed0-gpus2--1771791036        4
# hyperparam-sweep-4B-math2_deepscaler40k-Qwen3-4B-P16384-B16-S1-std-scale_lr-l4096-n4-lr4e-05-sigma0.001-r1-alpha1-seed0-gpus64--1771791140      3
# hyperparam-sweep-4B-math2_deepscaler40k-Qwen3-4B-P16384-B16-S1-std-scale_lr-l4096-n4-lr1.6e-05-sigma0.001-r1-alpha1-seed0-gpus64--1771791224    1
# Name: count, dtype: int64

# %%
rank3_run_top_runs = eval_results["rank3_run"].value_counts()
rank3_run_top_runs
# Out:
# rank3_run
# hyperparam-sweep-4B-math2_deepscaler40k-Qwen3-4B-P16384-B16-S1-std-scale_lr-l4096-n4-lr4e-05-sigma8e-05-r1-alpha1-seed0-gpus64--1771791488     5
# hyperparam-sweep-4B-math2_deepscaler40k-Qwen3-4B-P16384-B16-S1-std-scale_lr-l4096-n4-lr4e-05-sigma0.001-r1-alpha1-seed0-gpus64--1771791140     3
# hyperparam-sweep-4B-math2_deepscaler40k-Qwen3-4B-P16384-B16-S1-std-scale_lr-l4096-n4-lr4e-05-sigma0.0002-r1-alpha1-seed0-gpus64--1771791333    1
# hyperparam-sweep-4B-math2_deepscaler40k-Qwen3-4B-P512-B16-S1-std-scale_lr-l4096-n4-lr1.6e-05-sigma0.001-r1-alpha1-seed0-gpus2--1771791148      1
# hyperparam-sweep-4B-math2_deepscaler40k-Qwen3-4B-P512-B16-S1-std-scale_lr-l4096-n4-lr0.0002-sigma0.001-r1-alpha1-seed0-gpus2--1771791036       1
# hyperparam-sweep-4B-math2_deepscaler40k-Qwen3-4B-P16384-B16-S1-std-scale_lr-l4096-n4-lr0.0002-sigma0.001-r1-alpha1-seed0-gpus64--1771791074    1
# ...

# %%
eval_results[eval_results.rank1_run == "hyperparam-sweep-4B-math2_deepscaler40k-Qwen3-4B-P16384-B16-S1-std-scale_lr-l4096-n4-lr1.6e-05-sigma0.001-r1-alpha1-seed0-gpus64--1771791224"]
# Out:
#                        metric  step  \
# 5   eval/minerva_mean_fitness    20
# 8      eval/math_mean_fitness    20
# 11    eval/gsm8k_mean_fitness    20
# 14    eval/asdiv_mean_fitness    20
# 17      eval/amc_mean_fitness    20
# 20   eval/aime24_mean_fitness    20
#
#                                             rank1_run  rank1_value  \
# 5   hyperparam-sweep-4B-math2_deepscaler40k-Qwen3-...     0.343750
# 8   hyperparam-sweep-4B-math2_deepscaler40k-Qwen3-...     0.867188
# 11  hyperparam-sweep-4B-math2_deepscaler40k-Qwen3-...     0.882812
# 14  hyperparam-sweep-4B-math2_deepscaler40k-Qwen3-...     0.976562
# 17  hyperparam-sweep-4B-math2_deepscaler40k-Qwen3-...     0.523438
# 20  hyperparam-sweep-4B-math2_deepscaler40k-Qwen3-...     0.226562
#
#                                             rank2_run  rank2_value  \
# 5   hyperparam-sweep-4B-math2_deepscaler40k-Qwen3-...     0.320312
# 8   hyperparam-sweep-4B-math2_deepscaler40k-Qwen3-...     0.781250
# ...

# %%
eval_results[eval_results.rank1_run == "hyperparam-sweep-4B-math2_deepscaler40k-Qwen3-4B-P16384-B16-S1-std-scale_lr-l4096-n4-lr1.6e-05-sigma0.001-r1-alpha1-seed0-gpus64--1771791224"]
# Out:
#                        metric  step  \
# 5   eval/minerva_mean_fitness    20
# 8      eval/math_mean_fitness    20
# 11    eval/gsm8k_mean_fitness    20
# 14    eval/asdiv_mean_fitness    20
# 17      eval/amc_mean_fitness    20
# 20   eval/aime24_mean_fitness    20
#
#                                             rank1_run  rank1_value  \
# 5   hyperparam-sweep-4B-math2_deepscaler40k-Qwen3-...     0.343750
# 8   hyperparam-sweep-4B-math2_deepscaler40k-Qwen3-...     0.867188
# 11  hyperparam-sweep-4B-math2_deepscaler40k-Qwen3-...     0.882812
# 14  hyperparam-sweep-4B-math2_deepscaler40k-Qwen3-...     0.976562
# 17  hyperparam-sweep-4B-math2_deepscaler40k-Qwen3-...     0.523438
# 20  hyperparam-sweep-4B-math2_deepscaler40k-Qwen3-...     0.226562
#
#                                             rank2_run  rank2_value  \
# 5   hyperparam-sweep-4B-math2_deepscaler40k-Qwen3-...     0.320312
# 8   hyperparam-sweep-4B-math2_deepscaler40k-Qwen3-...     0.781250
# ...

# %%
eval_results.iloc[2]["rank3_run"]
# Out:
# 'hyperparam-sweep-4B-math2_deepscaler40k-Qwen3-4B-P16384-B16-S1-std-scale_lr-l4096-n4-lr4e-05-sigma0.0002-r1-alpha1-seed0-gpus64--1771791333'

# %% [markdown]
# ## Train Results

# %%
train_results = pd.read_csv("top_train_runs.csv")
train_results = train_results[train_results.step != 0]
train_results
# Out:
#           metric  step                                          rank1_run  \
# 1   mean_fitness     1  hyperparam-sweep-4B-math2_deepscaler40k-Qwen3-...
# 2   mean_fitness     2  hyperparam-sweep-4B-math2_deepscaler40k-Qwen3-...
# 3   mean_fitness     3  hyperparam-sweep-4B-math2_deepscaler40k-Qwen3-...
# 4   mean_fitness     4  hyperparam-sweep-4B-math2_deepscaler40k-Qwen3-...
# 5   mean_fitness     5  hyperparam-sweep-4B-math2_deepscaler40k-Qwen3-...
# 6   mean_fitness     6  hyperparam-sweep-4B-math2_deepscaler40k-Qwen3-...
# 7   mean_fitness     7  hyperparam-sweep-4B-math2_deepscaler40k-Qwen3-...
# 8   mean_fitness     8  hyperparam-sweep-4B-math2_deepscaler40k-Qwen3-...
# 9   mean_fitness     9  hyperparam-sweep-4B-math2_deepscaler40k-Qwen3-...
# 10  mean_fitness    10  hyperparam-sweep-4B-math2_deepscaler40k-Qwen3-...
# 11  mean_fitness    11  hyperparam-sweep-4B-math2_deepscaler40k-Qwen3-...
# 12  mean_fitness    12  hyperparam-sweep-4B-math2_deepscaler40k-Qwen3-...
# ...

# %%
train_results["rank1_run"].iloc[:].value_counts()
# Out:
# rank1_run
# hyperparam-sweep-4B-math2_deepscaler40k-Qwen3-4B-P16384-B16-S1-std-scale_lr-l4096-n4-lr0.0002-sigma0.001-r1-alpha1-seed0-gpus64--1771791074     11
# hyperparam-sweep-4B-math2_deepscaler40k-Qwen3-4B-P512-B16-S1-std-scale_lr-l4096-n4-lr0.0002-sigma0.001-r1-alpha1-seed0-gpus2--1771791036         5
# hyperparam-sweep-4B-math2_deepscaler40k-Qwen3-4B-P16384-B16-S1-std-scale_lr-l4096-n4-lr1.6e-05-sigma0.001-r1-alpha1-seed0-gpus64--1771791224     3
# hyperparam-sweep-4B-math2_deepscaler40k-Qwen3-4B-P16384-B16-S1-std-scale_lr-l4096-n4-lr4e-05-sigma0.0002-r1-alpha1-seed0-gpus64--1771791333      2
# Name: count, dtype: int64
